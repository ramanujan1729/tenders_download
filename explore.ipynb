# %%
import pandas as pd
import json

# %%
l = []
with open('/Users/archael/Downloads/all_tenders.json', 'r') as f:
    l = json.load(f)

df = pd.DataFrame(l)
df.head()
# Out:
#   clientType orderType tenderType          noticeType noticeTypeTed  \
# 0    1.1.1.1  Delivery      1.1.1      ContractNotice          None
# 1      1.1.2      None      1.1.1  NoticeUpdateNotice          None
# 2      1.1.6     Works      1.1.1      ContractNotice          None
# 3      1.1.2      None      1.1.1  NoticeUpdateNotice          None
# 4    1.1.1.1  Delivery      1.1.1      ContractNotice          None
#
#   noticeTypeDisplayName          noticeNumber          bzpNumber  \
# 0                  None  2025/BZP 00534256/01  2025/BZP 00534256
# 1                  None  2025/BZP 00534255/01  2025/BZP 00534255
# 2                  None  2025/BZP 00534254/01  2025/BZP 00534254
# 3                  None  2025/BZP 00534253/01  2025/BZP 00534253
# 4                  None  2025/BZP 00534252/01  2025/BZP 00534252
#
#   isTenderAmountBelowEU               publicationDate  ...  \
# 0                  True  2025-11-15T16:40:54.0765059Z  ...
# ...

# %%
df.orderType.value_counts()
# Out:
# orderType
# Services    31
# Delivery    27
# Works       20
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (100, 32)
