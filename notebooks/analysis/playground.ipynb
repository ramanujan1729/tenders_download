# %%
import pandas as pd
import json

# %%
l = []
with open('/Users/archael/Documents/Hubert/data/output/filtered_documents.txt', 'r') as f:
    l.extend(f.readlines())

# %%
ids = list(map(lambda x: x.split('/')[-2], l))

# %%
file = '/Users/archael/Documents/Hubert/data/output/kosztorys-ids.txt'

# %%
with open(file, 'w') as f:
    for id in set(ids):
        f.write(id + '\n')

# %%
len(set(ids))
# Out:
# 295
