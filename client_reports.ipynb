# %% [markdown]
# # Client Reports
#
# Generate reports for clients based on filtered tender documents.

# %%
import pandas as pd

# %%
l = []
with open('/Users/archael/Documents/Hubert/data/output/filtered_documents.txt', 'r') as f:
    l.extend(line.strip() for line in f)

l[0]
# Out:
# '/Users/archael/Documents/Hubert/data/tenders/ocds-148610-012bf214-1fdb-11ee-9aa3-96d3b4440790/1 Załącznik nr 1 Kosztorys ofertowy Konarskiego etap I z formułami.xlsx'

# %%
endings = list(map(lambda x: x.split('.')[-1], l))

# %%
from collections import Counter

cnt = Counter(endings)

# %%
cnt
# Out:
# Counter({'pdf': 169,
#          'xlsx': 114,
#          'xls': 49,
#          'zip': 44,
#          'doc': 39,
#          'docx': 36,
#          '7z': 17,
#          'ath': 13,
#          'rds7': 11,
#          'odt': 3,
#          'hst7': 2,
#          'rtf': 1,
#          'ods': 1,
#          '~rds7': 1,
#          'jpg': 1,
#          'kstx': 1})

# %% [markdown]
# # EDA
#
# # Parse excel files  -> csv -> whether we have a "cena" price column (we need pricing)
#     - Extract each table
#     - how many files we have the pricing for every position (row in the table)
#
#
# # Parse pdfs
#
# # Extract zips
#
# ## KNKRB 1 0101
# FINAL OBJECTIVE:

# %%
# which entitie organizes the tender 

# who is the organizer of this link

# %%
wrosraw
